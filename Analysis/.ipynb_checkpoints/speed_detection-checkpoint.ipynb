# %%
import numpy as np

# %%
timespan = np.array([9.6,4.923,3.291,2.487,1.967,1.646,1.413,1.236,1.106,0.992,0.912,0.836,0.767,0.709,0.653,0.610,0.584,0.551,0.520,0.495,0.474,0.444,0.426,0.410,0.395])

# %%
for i in timespan:
    print(i)
# Out:
# 9.6
# 4.923
# 3.291
# 2.487
# 1.967
# 1.646
# 1.413
# 1.236
# 1.106
# 0.992
# 0.912
# 0.836
# 0.767
# 0.709
# 0.653
# 0.61
# 0.584
# 0.551
# 0.52
# 0.495
# 0.474
# 0.444
# 0.426
# 0.41
# 0.395

# %%
voltage = np.array([2.6+i*0.1 for i in range(25)])

# %%
voltage
# Out:
# array([ 2.6,  2.7,  2.8,  2.9,  3. ,  3.1,  3.2,  3.3,  3.4,  3.5,  3.6,
#         3.7,  3.8,  3.9,  4. ,  4.1,  4.2,  4.3,  4.4,  4.5,  4.6,  4.7,
#         4.8,  4.9,  5. ])

# %%
import matplotlib.pyplot as plt
plt.plot(voltage,timespan)
plt.show()

# %%
y = 1024/timespan

# %%
y
# Out:
# array([  106.66666667,   208.00325005,   311.15162565,   411.74105348,
#          520.58973055,   622.11421628,   724.69922151,   828.4789644 ,
#          925.85895118,  1032.25806452,  1122.80701754,  1224.88038278,
#         1335.07170795,  1444.2877292 ,  1568.14701378,  1678.68852459,
#         1753.42465753,  1858.43920145,  1969.23076923,  2068.68686869,
#         2160.33755274,  2306.30630631,  2403.75586854,  2497.56097561,
#         2592.40506329])

# %%
plt.plot(voltage,y)
plt.show()

# %%
def aa(x):
    return x*1040-2605

# %%
l = aa(voltage)

# %%
l
# Out:
# array([   99.,   203.,   307.,   411.,   515.,   619.,   723.,   827.,
#          931.,  1035.,  1139.,  1243.,  1347.,  1451.,  1555.,  1659.,
#         1763.,  1867.,  1971.,  2075.,  2179.,  2283.,  2387.,  2491.,
#         2595.])

# %%
plt.plot(voltage,y)

plt.plot(voltage,l)

plt.show()
